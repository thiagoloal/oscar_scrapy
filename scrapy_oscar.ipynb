# %%
import pandas as pd
from bs4 import BeautifulSoup

#Get data from a html
#Parsing HTML from file and creating soup of tags
soup = BeautifulSoup(open("../oscar.html"), "html.parser")

# %% [markdown]
# ## Separando/organizando os dados
#
# Todas as edições do oscar são dividdas respectivamente em:
#
# **Ano > Categorias > Indicados > Vencedor**
#
# ### Variaveis
# * **HTML_editions:** HTML com edições
# * **categories:** DataFrame com todas as cetegorias | *categorie-year-winner*
# * **unique_categorie:** Dataframe com cada todas as categorias | *categorie-first_year-count*
# * **nominees:** DataFrame com todos os indicados | *name-year-movie-type-category-is_winner-is_movie*
# * **winners:** Dataframe com todos os vencedores | *nome-categoria-tipo-ano*

# %%
HTML_editions = soup.find_all("div", class_="awards-result-chron result-group group-awardcategory-chron")

editions = []

categories = []
nominees = []

special_categories = ['HONORARY FOREIGN LANGUAGE FILM AWARD', 'SPECIAL AWARD', 'HONORARY AWARD',
                      'IRVING G. THALBERG MEMORIAL AWARD','JEAN HERSHOLT HUMANITARIAN AWARD',
                      'SPECIAL FOREIGN LANGUAGE FILM AWARD']

for edition in HTML_editions:
    year = int(edition.find(class_="result-group-title").find('a').contents[0].split(' ')[0]) + 1
    HTML_category = edition.find_all("div", class_="subgroup-awardcategory-chron")
    
    editions.append([year, len(HTML_category)])
    
    for category in HTML_category:
        category_name = category.find(class_="result-subgroup-title").find('a').contents[0].rstrip()
        categories.append([year, category_name])
        HTML_nominee = category.find_all("div", class_="result-details")
        
        if category_name not in special_categories:
            stat = "awards-result-nominationstatement"
            title = "awards-result-film-title"
            
            for nominee in HTML_nominee:
                winner = False
                if nominee.find(class_='glyphicon-star'):
                    winner = True
                if nominee.find(class_=stat) is not None and nominee.find(class_=title) is not None:
                    nominee_name = nominee.find(class_=stat).find('a').contents[0].rstrip()
                    movie_name = nominee.find(class_=title).find('a').contents[0].rstrip() + '| ('+str(year)+')'
                    nominees.append([year,category_name,movie_name,nominee_name,winner])
                    
                elif nominee.find(class_=stat) is not None:
                    nominee_name = nominee.find(class_=stat).find('a').contents[0].rstrip()
                    nominees.append([year,category_name,False,nominee_name,winner])
                    
                elif nominee.find(class_=title) is not None:
                    movie_name = nominee.find(class_=title).find('a').contents[0].rstrip() + '| ('+str(year)+')'
                    nominees.append([year,category_name,movie_name,False,winner])

# %%
# Populate nominees
nominees = pd.DataFrame(nominees)
nominees.columns = ['year', 'category', 'movie', 'nominee', 'is_winner']
nominees.head()
# Out:
#    year category                     movie              nominee  is_winner
# 0  1929    ACTOR         The Noose| (1929)  Richard Barthelmess      False
# 1  1929    ACTOR  The Last Command| (1929)        Emil Jannings       True
# 2  1929  ACTRESS   A Ship Comes In| (1929)       Louise Dresser      False
# 3  1929  ACTRESS        7th Heaven| (1929)         Janet Gaynor       True
# 4  1929  ACTRESS    Sadie Thompson| (1929)       Gloria Swanson      False

# %%
# Dataframe with all winners
won = nominees[nominees['is_winner']].reset_index()
del won['index']
won.head()
# Out:
#    year        category                     movie                  nominee  \
# 0  1929           ACTOR  The Last Command| (1929)            Emil Jannings
# 1  1929         ACTRESS        7th Heaven| (1929)             Janet Gaynor
# 2  1929   ART DIRECTION         The Dove;| (1929)  William Cameron Menzies
# 3  1929  CINEMATOGRAPHY           Sunrise| (1929)           Charles Rosher
# 4  1929  CINEMATOGRAPHY           Sunrise| (1929)              Karl Struss
#
#    is_winner
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
import re

# function to determinate the type of category 
def typeMovie(category):
    if re.search("DIRECTING|DIRECTION|DIRECTOR", category) is not None:
        return 'DIRECTION'
    elif re.search("ACTOR|ACTRESS", category) is not None:
        return 'ACTORS'
    elif re.search("FILM|SHORT|DOCUMENTARY", category) is not None:
        return 'MOVIE'
    elif re.search("SOUND|MUSIC", category) is not None:
        return 'MUSIC'
    elif re.search("CINEMATOGRAPHY", category) is not None:
        return 'CINEMATOGRAPHY'
    elif re.search("WRITING", category) is not None:
        return 'WRITING'
    elif re.search("PRODUCTION", category) is not None:
        return 'PRODUCTION'
    else:
        return 'OTHER'

#function  to return the first year of category appear
def fist_year(category):
    df =  ct_year.loc[ct_year['category'] == category]
    return df['year'].min()

def indications(movie):
    df =  nominees.loc[nominees['movie'] == movie]
    return len(df)

def winner(movie):
    df =  nominees.loc[nominees['movie'] == movie]
    df = df[nominees['is_winner']]
    return len(df)

def movie_year(movie):
    df =  nominees.loc[nominees['movie'] == movie]
    return df['year'].min()

def splitter(movie):
    if movie is not False:
        return movie.split('|')[0]

# %%
categories = pd.DataFrame(categories)
categories.columns = ['year', 'category']
# ct_year: copy categories for use in first_year function

ct_year = categories.copy()
ct_year['first_year'] = ct_year['category'].apply(fist_year)
ct_year.head()
# Out:
#    year                    category  first_year
# 0  1929                       ACTOR        1929
# 1  1929                     ACTRESS        1929
# 2  1929               ART DIRECTION        1929
# 3  1929              CINEMATOGRAPHY        1929
# 4  1929  DIRECTING (Comedy Picture)        1929

# %%
unique_categorie = categories.groupby('category').count()
unique_categorie = unique_categorie.reset_index()
unique_categorie = unique_categorie.sort_values('year', ascending=False)
unique_categorie['first_year'] = unique_categorie['category'].apply(fist_year)

# format years to datetime and sorting
unique_categorie['type'] = unique_categorie['category'].apply(typeMovie)
unique_categorie = unique_categorie.set_index('category')

unique_categorie.head()
# Out:
#                               year  first_year       type
# category
# DIRECTING                       88        1930  DIRECTION
# FILM EDITING                    83        1935      MOVIE
# ACTOR IN A SUPPORTING ROLE      81        1937     ACTORS
# ACTRESS IN A SUPPORTING ROLE    81        1937     ACTORS
# DOCUMENTARY (Short Subject)     74        1942      MOVIE

# %% [markdown]
# ## Banco de pessoas e filmes
#
# Com todos as categorias, indicados e vencedores em **categories**, **nominees** e **winners** está na hora de pegar mais informações sobre os filmes, atores e diretores.
#
# Usando a API da Wikipedia para pegar mais informações e as imagens dos atores e filmes

# %%
editions = pd.DataFrame(editions)
editions.columns = ['year', 'participation']
editions['edition'] = [x+1 for x in range(len(editions.index.values))]
editions.head()
# Out:
#    year  participation  edition
# 0  1929             13        1
# 1  1930              7        2
# 2  1931              8        3
# 3  1932              9        4
# 4  1933             13        5

# %%
import numpy as np
movies = pd.DataFrame(np.unique(list(nominees['movie'])), columns=['movie'])
movies['year'] = movies['movie'].apply(movie_year)
movies['indications'] = movies['movie'].apply(indications)

#ERRO COM TITANIC - 2 filmes com o mesmo nome

# %%
movies['win'] = movies['movie'].apply(winner)
movies = movies.sort_values('indications', ascending=False)
movies['movie'] = movies['movie'].apply(splitter)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
def getWinner(year, category):
    if len(nominees.loc[(nominees['year'] == year) & (nominees['category'] == category) & (nominees['is_winner'] == True)].index) > 0:
        selec = nominees.loc[(nominees['year'] == year) & (nominees['category'] == category) & (nominees['is_winner'] == True)]
        if re.search("DIRECTING|DIRECTION|DIRECTOR|ACTOR|ACTRESS", category) is not None:
            return selec['nominee'].tolist()[0]
        elif re.search("FILM|SHORT|DOCUMENTARY|CINEMATOGRAPHY|WRITING|SOUND|MUSIC|PRODUCTION", category) is not None:
            return splitter(selec['movie'].tolist()[0])
        else:
            return selec['nominee'].tolist()[0]
    
    else:
        return None

for category in unique_categorie.index.values:
    editions[category] = editions['year'].apply(lambda x: getWinner(x, category))

    
editions
# Out:
#     year  participation  edition                 DIRECTING  \
# 0   1929             13        1                      None
# 1   1930              7        2               Frank Lloyd
# 2   1931              8        3           Lewis Milestone
# 3   1932              9        4             Norman Taurog
# 4   1933             13        5             Frank Borzage
# 5   1934             13        6               Frank Lloyd
# 6   1935             17        7               Frank Capra
# 7   1936             18        8                 John Ford
# 8   1937             21        9               Frank Capra
# 9   1938             22       10               Leo McCarey
# 10  1939             20       11               Frank Capra
# 11  1940             22       12            Victor Fleming
# 12  1941             23       13                 John Ford
# 13  1942             25       14                 John Ford
# 14  1943             25       15             William Wyler
# 15  1944             26       16            Michael Curtiz
# 16  1945             26       17               Leo McCarey
# 17  1946             25       18              Billy Wilder
# 18  1947             25       19             William Wyler
# 19  1948             25       20                Elia Kazan
# 20  1949             28       21               John Huston
# 21  1950             28       22      Joseph L. Mankiewicz
# 22  1951             29       23      Joseph L. Mankiewicz
# 23  1952             29       24            George Stevens
# 24  1953             29       25                 John Ford
# 25  1954             28       26            Fred Zinnemann
# 26  1955             28       27                Elia Kazan
# 27  1956             27       28              Delbert Mann
# 28  1957             30       29            George Stevens
# 29  1958             22       30                David Lean
# ..   ...            ...      ...                       ...
# 59  1988             24       60       Bernardo Bertolucci
# 60  1989             25       61            Barry Levinson
# 61  1990             25       62              Oliver Stone
# 62  1991             25       63             Kevin Costner
# 63  1992             25       64            Jonathan Demme
# 64  1993             25       65            Clint Eastwood
# 65  1994             25       66          Steven Spielberg
# 66  1995             26       67           Robert Zemeckis
# 67  1996             26       68                Mel Gibson
# 68  1997             26       69         Anthony Minghella
# 69  1998             25       70             James Cameron
# 70  1999             26       71          Steven Spielberg
# 71  2000             25       72                Sam Mendes
# 72  2001             25       73         Steven Soderbergh
# 73  2002             26       74                Ron Howard
# 74  2003             25       75            Roman Polanski
# 75  2004             25       76             Peter Jackson
# 76  2005             26       77            Clint Eastwood
# 77  2006             25       78                   Ang Lee
# 78  2007             26       79           Martin Scorsese
# 79  2008             25       80  Joel Coen and Ethan Coen
# 80  2009             25       81               Danny Boyle
# 81  2010             26       82           Kathryn Bigelow
# 82  2011             26       83                Tom Hooper
# 83  2012             26       84       Michel Hazanavicius
# 84  2013             26       85                   Ang Lee
# 85  2014             26       86            Alfonso Cuarón
# 86  2015             26       87     Alejandro G. Iñárritu
# 87  2016             26       88     Alejandro G. Iñárritu
# 88  2017             25       89           Damien Chazelle
#
#                                      FILM EDITING ACTOR IN A SUPPORTING ROLE  \
# 0                                            None                       None
# 1                                            None                       None
# 2                                            None                       None
# 3                                            None                       None
# 4                                            None                       None
# 5                                            None                       None
# 6                                          Eskimo                       None
# 7                       A Midsummer Night's Dream                       None
# 8                                 Anthony Adverse             Walter Brennan
# 9                                    Lost Horizon         Joseph Schildkraut
# 10                   The Adventures of Robin Hood             Walter Brennan
# 11                             Gone with the Wind            Thomas Mitchell
# 12                      North West Mounted Police             Walter Brennan
# 13                                  Sergeant York               Donald Crisp
# 14                       The Pride of the Yankees                 Van Heflin
# 15                                      Air Force             Charles Coburn
# 16                                         Wilson           Barry Fitzgerald
# 17                                National Velvet                 James Dunn
# 18                    The Best Years of Our Lives             Harold Russell
# 19                                  Body and Soul               Edmund Gwenn
# 20                                 The Naked City              Walter Huston
# 21                                       Champion                Dean Jagger
# 22                           King Solomon's Mines             George Sanders
# 23                             A Place in the Sun                Karl Malden
# 24                                      High Noon              Anthony Quinn
# 25                          From Here to Eternity              Frank Sinatra
# 26                              On the Waterfront             Edmond O'Brien
# 27                                         Picnic                Jack Lemmon
# 28                    Around the World in 80 Days              Anthony Quinn
# 29                   The Bridge on the River Kwai                Red Buttons
# ..                                            ...                        ...
# 59                               The Last Emperor               Sean Connery
# 60                        Who Framed Roger Rabbit                Kevin Kline
# 61                     Born on the Fourth of July          Denzel Washington
# 62                             Dances With Wolves                  Joe Pesci
# 63                                            JFK               Jack Palance
# 64                                     Unforgiven               Gene Hackman
# 65                               Schindler's List            Tommy Lee Jones
# 66                                   Forrest Gump              Martin Landau
# 67                                      Apollo 13               Kevin Spacey
# 68                            The English Patient          Cuba Gooding, Jr.
# 69                                        Titanic             Robin Williams
# 70                            Saving Private Ryan               James Coburn
# 71                                     The Matrix              Michael Caine
# 72                                        Traffic           Benicio Del Toro
# 73                                Black Hawk Down              Jim Broadbent
# 74                                        Chicago               Chris Cooper
# 75  The Lord of the Rings: The Return of the King                Tim Robbins
# 76                                    The Aviator             Morgan Freeman
# 77                                          Crash             George Clooney
# 78                                   The Departed                 Alan Arkin
# 79                           The Bourne Ultimatum              Javier Bardem
# 80                            Slumdog Millionaire               Heath Ledger
# 81                                The Hurt Locker            Christoph Waltz
# 82                             The Social Network             Christian Bale
# 83                The Girl with the Dragon Tattoo        Christopher Plummer
# 84                                           Argo            Christoph Waltz
# 85                                        Gravity                 Jared Leto
# 86                                       Whiplash               J.K. Simmons
# 87                             Mad Max: Fury Road               Mark Rylance
# 88                                  Hacksaw Ridge             Mahershala Ali
#
#    ACTRESS IN A SUPPORTING ROLE  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# 5                          None
# 6                          None
# 7                          None
# 8              Gale Sondergaard
# 9                   Alice Brady
# 10                  Fay Bainter
# 11              Hattie McDaniel
# 12                 Jane Darwell
# 13                   Mary Astor
# 14                Teresa Wright
# 15               Katina Paxinou
# 16              Ethel Barrymore
# 17                  Anne Revere
# 18                  Anne Baxter
# 19                 Celeste Holm
# 20                Claire Trevor
# 21         Mercedes McCambridge
# 22               Josephine Hull
# 23                   Kim Hunter
# 24               Gloria Grahame
# 25                   Donna Reed
# 26              Eva Marie Saint
# 27                 Jo Van Fleet
# 28               Dorothy Malone
# 29                Miyoshi Umeki
# ..                          ...
# 59              Olympia Dukakis
# 60                  Geena Davis
# 61               Brenda Fricker
# 62              Whoopi Goldberg
# 63               Mercedes Ruehl
# 64                 Marisa Tomei
# 65                  Anna Paquin
# 66                 Dianne Wiest
# 67                 Mira Sorvino
# 68             Juliette Binoche
# 69                 Kim Basinger
# 70                   Judi Dench
# 71               Angelina Jolie
# 72            Marcia Gay Harden
# 73            Jennifer Connelly
# 74         Catherine Zeta-Jones
# 75              Renée Zellweger
# 76               Cate Blanchett
# 77                 Rachel Weisz
# 78              Jennifer Hudson
# 79                Tilda Swinton
# 80                Penélope Cruz
# 81                     Mo'Nique
# 82                  Melissa Leo
# 83              Octavia Spencer
# 84                Anne Hathaway
# 85               Lupita Nyong'o
# 86            Patricia Arquette
# 87              Alicia Vikander
# 88                  Viola Davis
#
#                           DOCUMENTARY (Short Subject)  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                 Churchill's Island
# 14                                               None
# 15                                       December 7th
# 16                         With the Marines at Tarawa
# 17                                      Hitler Lives?
# 18                                   Seeds of Destiny
# 19                                        First Steps
# 20                                Toward Independence
# 21                                   A Chance to Live
# 22                                         Why Korea?
# 23                                              Benjy
# 24                                         Neighbours
# 25                                 The Alaskan Eskimo
# 26                                Thursday's Children
# 27                             Men against the Arctic
# 28                    The True Story of the Civil War
# 29                                               None
# ..                                                ...
# 59                                     Young at Heart
# 60                              You Don't Have to Die
# 61                                The Johnstown Flood
# 62                                    Days of Waiting
# 63  Deadly Deception: General Electric, Nuclear We...
# 64                                    Educating Peter
# 65                                Defending Our Lives
# 66                                 A Time for Justice
# 67                             One Survivor Remembers
# 68  Breathing Lessons: The Life and Work of Mark O...
# 69                                 A Story of Healing
# 70  The Personals: Improvisations on Romance in th...
# 71                                          King Gimp
# 72                                           Big Mama
# 73                                              Thoth
# 74                                        Twin Towers
# 75                                    Chernobyl Heart
# 76                 Mighty Times: The Children's March
# 77  A Note of Triumph: The Golden Age of Norman Co...
# 78                     The Blood of Yingzhou District
# 79                                           Freeheld
# 80                                        Smile Pinki
# 81                                  Music by Prudence
# 82                                  Strangers No More
# 83                                        Saving Face
# 84                                           Inocente
# 85          The Lady in Number 6: Music Saved My Life
# 86                   Crisis Hotline: Veterans Press 1
# 87      A Girl in the River: The Price of Forgiveness
# 88                                  The White Helmets
#
#                                 DOCUMENTARY (Feature)  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                     Desert Victory
# 16                                  The Fighting Lady
# 17                                     The True Glory
# 18                                               None
# 19                                   Design for Death
# 20                                    The Secret Land
# 21                                    Daybreak in Udi
# 22                   The Titan: Story of Michelangelo
# 23                                           Kon-Tiki
# 24                                  The Sea around Us
# 25                                  The Living Desert
# 26                              The Vanishing Prairie
# 27                          Helen Keller in Her Story
# 28                                   The Silent World
# 29                                  Albert Schweitzer
# ..                                                ...
# 59  The Ten-Year Lunch: The Wit and Legend of the ...
# 60  Hotel Terminus: The Life and Times of Klaus Ba...
# 61             Common Threads: Stories from the Quilt
# 62                                     American Dream
# 63                         In the Shadow of the Stars
# 64                               The Panama Deception
# 65  I Am a Promise: The Children of Stanton Elemen...
# 66                    Maya Lin: A Strong Clear Vision
# 67                              Anne Frank Remembered
# 68                                 When We Were Kings
# 69                                  The Long Way Home
# 70                                      The Last Days
# 71                               One Day in September
# 72  Into the Arms of Strangers: Stories of the Kin...
# 73                         Murder on a Sunday Morning
# 74                              Bowling for Columbine
# 75                                     The Fog of War
# 76                                 Born into Brothels
# 77                              March of the Penguins
# 78                              An Inconvenient Truth
# 79                              Taxi to the Dark Side
# 80                                        Man on Wire
# 81                                           The Cove
# 82                                         Inside Job
# 83                                         Undefeated
# 84                            Searching for Sugar Man
# 85                               20 Feet from Stardom
# 86                                        CitizenFour
# 87                                                Amy
# 88                              O.J.: Made in America
#
#                                        CINEMATOGRAPHY           ...            \
# 0                                             Sunrise           ...
# 1                     White Shadows in the South Seas           ...
# 2                         With Byrd at the South Pole           ...
# 3                                                Tabu           ...
# 4                                    Shanghai Express           ...
# 5                                  A Farewell to Arms           ...
# 6                                           Cleopatra           ...
# 7                           A Midsummer Night's Dream           ...
# 8                                     Anthony Adverse           ...
# 9                                      The Good Earth           ...
# 10                                    The Great Waltz           ...
# 11                                               None           ...
# 12                                               None           ...
# 13                                               None           ...
# 14                                               None           ...
# 15                                               None           ...
# 16                                               None           ...
# 17                                               None           ...
# 18                                               None           ...
# 19                                               None           ...
# 20                                               None           ...
# 21                                               None           ...
# 22                                               None           ...
# 23                                               None           ...
# 24                                               None           ...
# 25                                               None           ...
# 26                                               None           ...
# 27                                               None           ...
# 28                                               None           ...
# 29                       The Bridge on the River Kwai           ...
# ..                                                ...           ...
# 59                                   The Last Emperor           ...
# 60                                Mississippi Burning           ...
# 61                                              Glory           ...
# 62                                 Dances With Wolves           ...
# 63                                                JFK           ...
# 64                            A River Runs through It           ...
# 65                                   Schindler's List           ...
# 66                                Legends of the Fall           ...
# 67                                         Braveheart           ...
# 68                                The English Patient           ...
# 69                                            Titanic           ...
# 70                                Saving Private Ryan           ...
# 71                                    American Beauty           ...
# 72                     Crouching Tiger, Hidden Dragon           ...
# 73  The Lord of the Rings: The Fellowship of the Ring           ...
# 74                                  Road to Perdition           ...
# 75    Master and Commander: The Far Side of the World           ...
# 76                                        The Aviator           ...
# 77                                Memoirs of a Geisha           ...
# 78                                    Pan's Labyrinth           ...
# 79                                There Will Be Blood           ...
# 80                                Slumdog Millionaire           ...
# 81                                             Avatar           ...
# 82                                          Inception           ...
# 83                                               Hugo           ...
# 84                                         Life of Pi           ...
# 85                                            Gravity           ...
# 86    Birdman or (The Unexpected Virtue of Ignorance)           ...
# 87                                       The Revenant           ...
# 88                                         La La Land           ...
#
#    SPECIAL ACHIEVEMENT AWARD (Sound Effects)  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 6                                       None
# 7                                       None
# 8                                       None
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                      None
# 17                                      None
# 18                                      None
# 19                                      None
# 20                                      None
# 21                                      None
# 22                                      None
# 23                                      None
# 24                                      None
# 25                                      None
# 26                                      None
# 27                                      None
# 28                                      None
# 29                                      None
# ..                                       ...
# 59                                      None
# 60                                      None
# 61                                      None
# 62                                      None
# 63                                      None
# 64                                      None
# 65                                      None
# 66                                      None
# 67                                      None
# 68                                      None
# 69                                      None
# 70                                      None
# 71                                      None
# 72                                      None
# 73                                      None
# 74                                      None
# 75                                      None
# 76                                      None
# 77                                      None
# 78                                      None
# 79                                      None
# 80                                      None
# 81                                      None
# 82                                      None
# 83                                      None
# 84                                      None
# 85                                      None
# 86                                      None
# 87                                      None
# 88                                      None
#
#    SPECIAL ACHIEVEMENT AWARD (Sound Editing)           DOCUMENTARY  \
# 0                                       None                  None
# 1                                       None                  None
# 2                                       None                  None
# 3                                       None                  None
# 4                                       None                  None
# 5                                       None                  None
# 6                                       None                  None
# 7                                       None                  None
# 8                                       None                  None
# 9                                       None                  None
# 10                                      None                  None
# 11                                      None                  None
# 12                                      None                  None
# 13                                      None                  None
# 14                                      None  The Battle of Midway
# 15                                      None                  None
# 16                                      None                  None
# 17                                      None                  None
# 18                                      None                  None
# 19                                      None                  None
# 20                                      None                  None
# 21                                      None                  None
# 22                                      None                  None
# 23                                      None                  None
# 24                                      None                  None
# 25                                      None                  None
# 26                                      None                  None
# 27                                      None                  None
# 28                                      None                  None
# 29                                      None                  None
# ..                                       ...                   ...
# 59                                      None                  None
# 60                                      None                  None
# 61                                      None                  None
# 62                                      None                  None
# 63                                      None                  None
# 64                                      None                  None
# 65                                      None                  None
# 66                                      None                  None
# 67                                      None                  None
# 68                                      None                  None
# 69                                      None                  None
# 70                                      None                  None
# 71                                      None                  None
# 72                                      None                  None
# 73                                      None                  None
# 74                                      None                  None
# 75                                      None                  None
# 76                                      None                  None
# 77                                      None                  None
# 78                                      None                  None
# 79                                      None                  None
# 80                                      None                  None
# 81                                      None                  None
# 82                                      None                  None
# 83                                      None                  None
# 84                                      None                  None
# 85                                      None                  None
# 86                                      None                  None
# 87                                      None                  None
# 88                                      None                  None
#
#    SHORT FILM (Dramatic Live Action)  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# 5                               None
# 6                               None
# 7                               None
# 8                               None
# 9                               None
# 10                              None
# 11                              None
# 12                              None
# 13                              None
# 14                              None
# 15                              None
# 16                              None
# 17                              None
# 18                              None
# 19                              None
# 20                              None
# 21                              None
# 22                              None
# 23                              None
# 24                              None
# 25                              None
# 26                              None
# 27                              None
# 28                              None
# 29                              None
# ..                               ...
# 59                              None
# 60                              None
# 61                              None
# 62                              None
# 63                              None
# 64                              None
# 65                              None
# 66                              None
# 67                              None
# 68                              None
# 69                              None
# 70                              None
# 71                              None
# 72                              None
# 73                              None
# 74                              None
# 75                              None
# 76                              None
# 77                              None
# 78                              None
# 79                              None
# 80                              None
# 81                              None
# 82                              None
# 83                              None
# 84                              None
# 85                              None
# 86                              None
# 87                              None
# 88                              None
#
#    MUSIC (Original Song Score or Adaptation Score)  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                             None
# 6                                             None
# 7                                             None
# 8                                             None
# 9                                             None
# 10                                            None
# 11                                            None
# 12                                            None
# 13                                            None
# 14                                            None
# 15                                            None
# 16                                            None
# 17                                            None
# 18                                            None
# 19                                            None
# 20                                            None
# 21                                            None
# 22                                            None
# 23                                            None
# 24                                            None
# 25                                            None
# 26                                            None
# 27                                            None
# 28                                            None
# 29                                            None
# ..                                             ...
# 59                                            None
# 60                                            None
# 61                                            None
# 62                                            None
# 63                                            None
# 64                                            None
# 65                                            None
# 66                                            None
# 67                                            None
# 68                                            None
# 69                                            None
# 70                                            None
# 71                                            None
# 72                                            None
# 73                                            None
# 74                                            None
# 75                                            None
# 76                                            None
# 77                                            None
# 78                                            None
# 79                                            None
# 80                                            None
# 81                                            None
# 82                                            None
# 83                                            None
# 84                                            None
# 85                                            None
# 86                                            None
# 87                                            None
# 88                                            None
#
#    MUSIC (Music Score of a Dramatic Picture) MUSIC (Adaptation Score)  \
# 0                                       None                     None
# 1                                       None                     None
# 2                                       None                     None
# 3                                       None                     None
# 4                                       None                     None
# 5                                       None                     None
# 6                                       None                     None
# 7                                       None                     None
# 8                                       None                     None
# 9                                       None                     None
# 10                                      None                     None
# 11                                      None                     None
# 12                                      None                     None
# 13                    All That Money Can Buy                     None
# 14                                      None                     None
# 15                                      None                     None
# 16                                      None                     None
# 17                                      None                     None
# 18                                      None                     None
# 19                                      None                     None
# 20                                      None                     None
# 21                                      None                     None
# 22                                      None                     None
# 23                                      None                     None
# 24                                      None                     None
# 25                                      None                     None
# 26                                      None                     None
# 27                                      None                     None
# 28                                      None                     None
# 29                                      None                     None
# ..                                       ...                      ...
# 59                                      None                     None
# 60                                      None                     None
# 61                                      None                     None
# 62                                      None                     None
# 63                                      None                     None
# 64                                      None                     None
# 65                                      None                     None
# 66                                      None                     None
# 67                                      None                     None
# 68                                      None                     None
# 69                                      None                     None
# 70                                      None                     None
# 71                                      None                     None
# 72                                      None                     None
# 73                                      None                     None
# 74                                      None                     None
# 75                                      None                     None
# 76                                      None                     None
# 77                                      None                     None
# 78                                      None                     None
# 79                                      None                     None
# 80                                      None                     None
# 81                                      None                     None
# 82                                      None                     None
# 83                                      None                     None
# 84                                      None                     None
# 85                                      None                     None
# 86                                      None                     None
# 87                                      None                     None
# 88                                      None                     None
#
#    DIRECTING (Comedy Picture) DIRECTING (Dramatic Picture)  \
# 0             Lewis Milestone                Frank Borzage
# 1                        None                         None
# 2                        None                         None
# 3                        None                         None
# 4                        None                         None
# 5                        None                         None
# 6                        None                         None
# 7                        None                         None
# 8                        None                         None
# 9                        None                         None
# 10                       None                         None
# 11                       None                         None
# 12                       None                         None
# 13                       None                         None
# 14                       None                         None
# 15                       None                         None
# 16                       None                         None
# 17                       None                         None
# 18                       None                         None
# 19                       None                         None
# 20                       None                         None
# 21                       None                         None
# 22                       None                         None
# 23                       None                         None
# 24                       None                         None
# 25                       None                         None
# 26                       None                         None
# 27                       None                         None
# 28                       None                         None
# 29                       None                         None
# ..                        ...                          ...
# 59                       None                         None
# 60                       None                         None
# 61                       None                         None
# 62                       None                         None
# 63                       None                         None
# 64                       None                         None
# 65                       None                         None
# 66                       None                         None
# 67                       None                         None
# 68                       None                         None
# 69                       None                         None
# 70                       None                         None
# 71                       None                         None
# 72                       None                         None
# 73                       None                         None
# 74                       None                         None
# 75                       None                         None
# 76                       None                         None
# 77                       None                         None
# 78                       None                         None
# 79                       None                         None
# 80                       None                         None
# 81                       None                         None
# 82                       None                         None
# 83                       None                         None
# 84                       None                         None
# 85                       None                         None
# 86                       None                         None
# 87                       None                         None
# 88                       None                         None
#
#    WRITING (Title Writing)
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# 5                     None
# 6                     None
# 7                     None
# 8                     None
# 9                     None
# 10                    None
# 11                    None
# 12                    None
# 13                    None
# 14                    None
# 15                    None
# 16                    None
# 17                    None
# 18                    None
# 19                    None
# 20                    None
# 21                    None
# 22                    None
# 23                    None
# 24                    None
# 25                    None
# 26                    None
# 27                    None
# 28                    None
# 29                    None
# ..                     ...
# 59                    None
# 60                    None
# 61                    None
# 62                    None
# 63                    None
# 64                    None
# 65                    None
# 66                    None
# 67                    None
# 68                    None
# 69                    None
# 70                    None
# 71                    None
# 72                    None
# 73                    None
# 74                    None
# 75                    None
# 76                    None
# 77                    None
# 78                    None
# 79                    None
# 80                    None
# 81                    None
# 82                    None
# 83                    None
# 84                    None
# 85                    None
# 86                    None
# 87                    None
# 88                    None
#
# [89 rows x 113 columns]

# %%
movies = movies.set_index('movie')
movies = movies.drop(movies.index[-1])
movies.head()
# Out:
#                                        year  indications  win
# movie
# All about Eve                        1951.0           14    6
# Titanic                              1998.0           14   11
# La La Land                           2017.0           14    6
# Gone with the Wind                   1940.0           13    8
# The Curious Case of Benjamin Button  2009.0           13    3

# %% [markdown]
# # Salvando
#
# Salvando informações em um csv para usar em outro notebook **movies_local.csv**

# %%
nominees.to_csv('./database/nominees_local.csv')

unique_categorie.to_csv('./database/unique_categorie.csv')

movies.to_csv('./database/movies_local.csv')

editions.to_csv('./database/all_editions.csv')

# %%
excel = pd.ExcelWriter('./database/oscar_local.xlsx')
editions.to_excel(excel,'Edições')
nominees.to_excel(excel,'Todos os indicados')
unique_categorie.to_excel(excel,'Todas as Categorias')
movies.to_excel(excel,'Filmes indicados')
excel.save()

# %%
# from tmdbv3api import Movie
# from tmdbv3api import TMDb

# movie = Movie()
# tmdb = TMDb()

# tmdb.api_key = 'aa043c2ae33192f63fcc150bb97816b7'

# def find_movie(mv):
#     search = movie.search(mv)
#     return len(search)

# %%
# movies['same_titles'] = [find_movie(x) for x in movies.index.values]

# %%
# no_match = movies.loc[movies['same_titles'] == 0]

# %%
# no_match

# %%
# bigger_then = movies.loc[movies['same_titles'] > 1].sort_values('same_titles', ascending=False)
# bigger_then

# %%
# unique = movies.loc[movies['same_titles'] == 1]
# unique

# %%
# from tmdbv3api import Movie
# from tmdbv3api import TMDb

# movie = Movie()
# tmdb = TMDb()

# tmdb.api_key = 'aa043c2ae33192f63fcc150bb97816b7'

# teste = movie.search('Titanic')

# teste

# %%
#tmdbv3api
#omdb
#imdb
# year | director | image | imdb_rate | categories | duration | budget | return | country | language

# %%
# unique
